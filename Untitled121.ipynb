# %%
data_dir = r"C:\Users\Pratyush\Pictures\Face\data"
vgg16weight = r"C:\Users\Pratyush\Downloads\vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"
resnet50weight = r"C:\Users\Pratyush\Downloads\resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, Sequential
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.optimizers import RMSprop, SGD
from keras import backend as K
import keras
import matplotlib.pyplot as plt

# %%
import os
img_width, img_height = 200, 200
train_data_dir = os.path.join(data_dir, 'train')
validation_data_dir = os.path.join(data_dir, 'val')
nb_train_samples = 93
nb_validation_samples = 25
epochs = 50
batch_size = 16
numclasses = 5
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=10,  
    zoom_range = 0.1,  
    width_shift_range=0.1,  
    height_shift_range=0.1,  
    vertical_flip=False,
    horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1. / 255)
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 93 images belonging to 5 classes.
# Found 25 images belonging to 5 classes.

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)
def vgg16CNNtl(input_shape, outclass, sigma='sigmoid'):    
    base_model = None
    base_model = keras.applications.VGG16(weights=None, include_top=False, input_shape=input_shape)
    base_model.load_weights(vgg16weight)
    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    for i in range(2):
        top_model.add(Dense(4096, activation='relu'))
        top_model.add(Dropout(0.5))
    top_model.add(Dense(outclass, activation=sigma))
    model = None
    model = Model(inputs=base_model.input, outputs=top_model(base_model.output))    
    return model
 
def resnet50tl(input_shape, outclass, sigma='sigmoid'):    
    base_model = None
    base_model = keras.applications.resnet50.ResNet50(weights=None, include_top=False, input_shape=input_shape)
    base_model.load_weights(resnet50weight)    
    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    for i in range(2):
        top_model.add(Dense(4096, activation='relu'))
        top_model.add(Dropout(0.5))
    top_model.add(Dense(outclass, activation=sigma))
    model = None
    model = Model(inputs=base_model.input, outputs=top_model(base_model.output))    
    return model

# %%
model = vgg16CNNtl(input_shape, numclasses, 'softmax')
lr = 1e-5
decay = 1e-7
optimizer = RMSprop(lr=lr, decay=decay)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From <ipython-input-48-50dac1443f25>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 5/5 [==============================] - 72s 14s/step - loss: 1.8889 - accuracy: 0.2500 - val_loss: 1.5539 - val_accuracy: 0.2500
# Epoch 2/50
# 5/5 [==============================] - 60s 12s/step - loss: 1.7987 - accuracy: 0.2000 - val_loss: 1.4088 - val_accuracy: 0.5000
# Epoch 3/50
# 5/5 [==============================] - 59s 12s/step - loss: 1.5652 - accuracy: 0.4000 - val_loss: 1.4603 - val_accuracy: 0.5000
# Epoch 4/50
# 5/5 [==============================] - 56s 11s/step - loss: 1.5322 - accuracy: 0.4026 - val_loss: 1.3590 - val_accuracy: 0.6250
# Epoch 5/50
# 5/5 [==============================] - 59s 12s/step - loss: 1.5229 - accuracy: 0.3377 - val_loss: 1.3400 - val_accuracy: 0.5000
# Epoch 6/50
# 5/5 [==============================] - 58s 12s/step - loss: 1.5920 - accuracy: 0.2857 - val_loss: 1.2806 - val_accuracy: 0.4375
# Epoch 7/50
# 5/5 [==============================] - 56s 11s/step - loss: 1.3689 - accuracy: 0.4286 - val_loss: 1.0788 - val_accuracy: 0.5625
# Epoch 8/50
# 5/5 [==============================] - 59s 12s/step - loss: 1.3813 - accuracy: 0.4250 - val_loss: 1.1853 - val_accuracy: 0.4375
# Epoch 9/50
# 5/5 [==============================] - 58s 12s/step - loss: 1.1372 - accuracy: 0.5875 - val_loss: 1.0550 - val_accuracy: 0.5625
# Epoch 10/50
# 5/5 [==============================] - 58s 12s/step - loss: 0.9245 - accuracy: 0.6375 - val_loss: 0.8956 - val_accuracy: 0.6250
# Epoch 11/50
# 5/5 [==============================] - 57s 11s/step - loss: 0.8210 - accuracy: 0.7273 - val_loss: 0.8918 - val_accuracy: 0.6875
# Epoch 12/50
# 5/5 [==============================] - 58s 12s/step - loss: 0.7944 - accuracy: 0.7273 - val_loss: 0.9240 - val_accuracy: 0.5000
# Epoch 13/50
# 5/5 [==============================] - 56s 11s/step - loss: 0.7798 - accuracy: 0.6494 - val_loss: 0.6165 - val_accuracy: 0.8125
# Epoch 14/50
# 5/5 [==============================] - 57s 11s/step - loss: 0.7284 - accuracy: 0.7273 - val_loss: 0.6046 - val_accuracy: 0.6875
# Epoch 15/50
# 5/5 [==============================] - 53s 11s/step - loss: 0.7534 - accuracy: 0.7273 - val_loss: 0.6961 - val_accuracy: 0.7500
# Epoch 16/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.5215 - accuracy: 0.8250 - val_loss: 0.6556 - val_accuracy: 0.7500
# Epoch 17/50
# 5/5 [==============================] - 45s 9s/step - loss: 0.5733 - accuracy: 0.8182 - val_loss: 0.6085 - val_accuracy: 0.7500
# Epoch 18/50
# 5/5 [==============================] - 45s 9s/step - loss: 0.5628 - accuracy: 0.7662 - val_loss: 0.4847 - val_accuracy: 0.8125
# Epoch 19/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.4866 - accuracy: 0.8125 - val_loss: 0.4537 - val_accuracy: 0.9375
# Epoch 20/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.2410 - accuracy: 0.9481 - val_loss: 0.3534 - val_accuracy: 0.9375
# Epoch 21/50
# 5/5 [==============================] - 53s 11s/step - loss: 0.4849 - accuracy: 0.8442 - val_loss: 0.1946 - val_accuracy: 1.0000
# Epoch 22/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.3539 - accuracy: 0.8961 - val_loss: 0.4829 - val_accuracy: 0.8750
# Epoch 23/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.3277 - accuracy: 0.8875 - val_loss: 0.2627 - val_accuracy: 0.9375
# Epoch 24/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.2724 - accuracy: 0.9221 - val_loss: 0.4576 - val_accuracy: 0.9375
# Epoch 25/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.1941 - accuracy: 0.9481 - val_loss: 0.4204 - val_accuracy: 0.9375
# Epoch 26/50
# 5/5 [==============================] - 50s 10s/step - loss: 0.2733 - accuracy: 0.9250 - val_loss: 0.2009 - val_accuracy: 0.9375
# Epoch 27/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.2961 - accuracy: 0.9091 - val_loss: 0.3153 - val_accuracy: 0.9375
# Epoch 28/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.1901 - accuracy: 0.9221 - val_loss: 0.4015 - val_accuracy: 0.8750
# Epoch 29/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.1352 - accuracy: 0.9351 - val_loss: 0.3867 - val_accuracy: 0.8750
# Epoch 30/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.0968 - accuracy: 0.9875 - val_loss: 0.3983 - val_accuracy: 0.8125
# Epoch 31/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.1350 - accuracy: 0.9481 - val_loss: 0.2000 - val_accuracy: 0.9375
# Epoch 32/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.0998 - accuracy: 0.9870 - val_loss: 0.0991 - val_accuracy: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0792 - accuracy: 0.9750 - val_loss: 0.1194 - val_accuracy: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.1102 - accuracy: 0.9481 - val_loss: 0.1378 - val_accuracy: 0.9375
# Epoch 35/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0819 - accuracy: 0.9870 - val_loss: 0.3260 - val_accuracy: 0.9375
# Epoch 36/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.0642 - accuracy: 0.9870 - val_loss: 0.3685 - val_accuracy: 0.9375
# Epoch 37/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.0686 - accuracy: 0.9870 - val_loss: 0.1325 - val_accuracy: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.0750 - accuracy: 0.9610 - val_loss: 0.0792 - val_accuracy: 0.9375
# Epoch 39/50
# 5/5 [==============================] - 50s 10s/step - loss: 0.1243 - accuracy: 0.9610 - val_loss: 0.1718 - val_accuracy: 0.9375
# Epoch 40/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.0426 - accuracy: 0.9870 - val_loss: 0.3335 - val_accuracy: 0.9375
# Epoch 41/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.0810 - accuracy: 0.9870 - val_loss: 0.3709 - val_accuracy: 0.8750
# Epoch 42/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.3978 - val_accuracy: 0.9375
# Epoch 43/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.4158 - val_accuracy: 0.8750
# Epoch 45/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.1926 - accuracy: 0.9221 - val_loss: 0.3409 - val_accuracy: 0.8750
# Epoch 46/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0380 - accuracy: 0.9870 - val_loss: 0.5115 - val_accuracy: 0.8125
# Epoch 47/50
# 5/5 [==============================] - 52s 10s/step - loss: 0.0537 - accuracy: 0.9740 - val_loss: 0.5110 - val_accuracy: 0.8750
# Epoch 48/50
# 5/5 [==============================] - 55s 11s/step - loss: 0.0279 - accuracy: 0.9870 - val_loss: 0.1909 - val_accuracy: 0.9375
# Epoch 49/50
# 5/5 [==============================] - 61s 12s/step - loss: 0.0525 - accuracy: 0.9750 - val_loss: 0.3771 - val_accuracy: 0.8125
# Epoch 50/50
# 5/5 [==============================] - 60s 12s/step - loss: 0.0476 - accuracy: 0.9740 - val_loss: 0.3851 - val_accuracy: 0.8125

# %%
training_loss = history.history['loss']
training_acc = history.history['accuracy']
epoch_count = range(1, len(training_loss) + 1)
fig=plt.figure(figsize=(12, 4))
fig.add_subplot(121)
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, training_acc, 'b-')
plt.legend(['Training Loss', 'Training Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Training Loss/Acc')
val_acc = history.history['val_accuracy']
training_acc = history.history['accuracy']
epoch_count = range(1, len(val_acc) + 1)
fig.add_subplot(122)
plt.plot(epoch_count, val_acc, 'r--')
plt.plot(epoch_count, training_acc, 'b-')
plt.legend(['Validation Accuracy', 'Training Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show();

# %%
saveweight =  r"C:\Users\Pratyush\Pictures\filesave.h5\celebriytag_weight.h5"
model.save_weights(saveweight)

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from io import BytesIO
import cv2
import requests
import os

# %%
def predictimage(path):
    labels = ['ben_afflek',  'elton_john',  'jerry_seinfeld',  'madonna',  'mindy_kaling']
    test_imgs = [path]

    for test in test_imgs:
        test_img = os.path.join(validation_data_dir, test)
        img = image.load_img(test_img, target_size=(img_width, img_height))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x /= 255.
        classes = model.predict(x)
        result = np.squeeze(classes)
        result_indices = np.argmax(result)

        img = cv2.imread(test_img, cv2.IMREAD_COLOR)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.axis('off')
        plt.title("{}, {:.2f}%".format(labels[result_indices], result[result_indices]*100))
        plt.imshow(img)

        #print("{}, {:.2f}%".format(labels[result_indices], result[result_indices]*100))

# %%
path=r"C:\Users\Pratyush\Pictures\Face\data\train\ben_afflek\httpimagesfandangocomrImageRendererredesignstaticimgnoxportraitjpgpcpcpcimagesmasterrepositoryperformerimagespjpg.jpg"
predictimage(path)
